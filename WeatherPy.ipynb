# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\busyd\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\busyd\anaconda3\lib\site-packages (from citipy) (0.16)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy as cp

# %%
#Grab list of cities based on coordinates from citipy
citylist = []
count = 0
dup = 'no'

for x in range(-90,90,1):
    for y in range(-180,180,1):
        city = cp.nearest_city(x, y)
        citdict = {}
        citdict['city'] = city.city_name
        citdict['country'] = city.country_code
        citdict['lat'] = x
        citdict['long'] = y
        if len(citylist) == 0:
            citylist.append(citdict)
            count+=1
            continue
        else:
            #Get rid of duplicates
            for city in citylist:
                if city['city'] == citdict['city']:
                    dup = 'yes'
        if dup == 'no':
            citylist.append(citdict)
            count+=1
        else:
            dup = 'no'

print(len(citylist))
# Out:
# 7957

# %%
# List for holding lat_lngs and cities
citypd = pd.DataFrame({
    'city': [x['city'] for x in citylist],
    'country': [x['country'] for x in citylist],
})

citypd.head()

samplecity = citypd.sample(500)

# %%
samplecity
# Out:
#                      city country
# 7237             poddorye      ru
# 783           sao gotardo      br
# 6025              rassvet      ru
# 6993           westerland      de
# 2040                kembe      cf
# 3995              sonipat      in
# 1431            purwodadi      id
# 105        lakes entrance      au
# 3549     vicente guerrero      mx
# 1243              merauke      id
# 4674                 sari      ir
# 7725           porosozero      ru
# 5654       terekli-mekteb      ru
# 5813               yakima      us
# 3365               mahuva      in
# 4268           huangchuan      cn
# 1029                 sola      vu
# 7849            rovaniemi      fi
# 490         kawana waters      au
# 305                 salto      uy
# 1501                 jati      id
# 2022               orocue      co
# 2069            sarangani      ph
# 7845               kiruna      se
# 2181                baoro      cf
# 3972             bardiyah      ly
# 3207             frontera      mx
# 3289               jiddah      sa
# 5537                merke      kz
# 6108          bad wurzach      de
# ...                   ...     ...
# 2952              biltine      td
# 956            pedra azul      br
# 1054           livramento      br
# 4354             dengzhou      cn
# 4723              liberal      us
# 6744              munster      de
# 7594             valkeala      fi
# 187                  teno      cl
# 7021           lukhovitsy      ru
# 2                 rikitea      pf
# 4734               murray      us
# 929                  fare      pf
# 3164               alibag      in
# 1531         areia branca      br
# 6640          ivanteyevka      ru
# 6204       iroquois falls      ca
# 1592                maues      br
# 2699              galgani      sd
# 4151               mehriz      ir
# 3080            sandy bay      hn
# 5040                seydi      tm
# 2219           san isidro      ph
# 3243               teknaf      bd
# 4910              siverek      tr
# 6584           killorglin      ie
# 1959           butaritari      ki
# 5666               tekeli      kz
# 5112  castanheira de pera      pt
# 4746           louisbourg      ca
# 7220             halmstad      se
#
# [500 rows x 2 columns]

# %% [markdown]
# ## Generate Cities List

# %%
import requests as req
import json

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c539901c6834> in <module>()
#       9 # Identify nearest city for each lat, lng combination
#      10 for lat_lng in lat_lngs:
# ---> 11     city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#      12
#      13     # If the city is unique, then add it to a our cities list
#
# NameError: name 'citipy' is not defined

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
apikey = '25bc90a1196e6f153eece0bc0b0fc9eb'
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
count = 0
samplecity['latitude'] = ""
samplecity['longitude'] = ""
samplecity['temperature'] = ""
samplecity['humidity'] = ""
samplecity['cloudiness'] = ""
samplecity['wind_speed'] = ""

for index,row in samplecity.iterrows():
    count+= 1
    query_url = url + "appid=" + apikey + "&units=" + units + "&q=" + row['city']
    try:
        weather_response = req.get(query_url)
        cityweather = weather_response.json()
#         print(cityweather)
        samplecity.set_value(index, "latitude", int(cityweather['coord']['lat']))
        samplecity.set_value(index, "longitude", int(cityweather['coord']['lat']))
        samplecity.set_value(index, "temperature", int(cityweather['main']['temp']))
        samplecity.set_value(index, "humidity", int(cityweather['main']['humidity']))
        samplecity.set_value(index, "cloudiness", int(cityweather['clouds']['all']))
        samplecity.set_value(index, "wind_speed", int(cityweather['wind']['speed']))
    except:
        print(f"No data for this city: {row['city']}")
    print(f"This is city#: {count}")
    print(f"This is: {row['city']}" )
    print(f"This is the requested URL: {query_url}")
# Out:
# C:\Users\busyd\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\busyd\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\busyd\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\busyd\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\busyd\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\busyd\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# This is city#: 1
# This is: poddorye
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=poddorye
# This is city#: 2
# This is: sao gotardo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sao gotardo
# This is city#: 3
# This is: rassvet
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=rassvet
# This is city#: 4
# This is: westerland
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=westerland
# No data for this city: kembe
# This is city#: 5
# This is: kembe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kembe
# This is city#: 6
# This is: sonipat
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sonipat
# This is city#: 7
# This is: purwodadi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=purwodadi
# This is city#: 8
# This is: lakes entrance
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=lakes entrance
# This is city#: 9
# This is: vicente guerrero
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=vicente guerrero
# This is city#: 10
# This is: merauke
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=merauke
# This is city#: 11
# This is: sari
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sari
# This is city#: 12
# This is: porosozero
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=porosozero
# This is city#: 13
# This is: terekli-mekteb
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=terekli-mekteb
# This is city#: 14
# This is: yakima
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=yakima
# This is city#: 15
# This is: mahuva
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mahuva
# This is city#: 16
# This is: huangchuan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=huangchuan
# This is city#: 17
# This is: sola
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sola
# This is city#: 18
# This is: rovaniemi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=rovaniemi
# No data for this city: kawana waters
# This is city#: 19
# This is: kawana waters
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kawana waters
# This is city#: 20
# This is: salto
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=salto
# This is city#: 21
# This is: jati
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=jati
# This is city#: 22
# This is: orocue
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=orocue
# This is city#: 23
# This is: sarangani
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sarangani
# This is city#: 24
# This is: kiruna
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kiruna
# This is city#: 25
# This is: baoro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=baoro
# No data for this city: bardiyah
# This is city#: 26
# This is: bardiyah
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bardiyah
# This is city#: 27
# This is: frontera
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=frontera
# No data for this city: jiddah
# This is city#: 28
# This is: jiddah
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=jiddah
# This is city#: 29
# This is: merke
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=merke
# This is city#: 30
# This is: bad wurzach
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bad wurzach
# This is city#: 31
# This is: yeppoon
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=yeppoon
# This is city#: 32
# This is: glens falls
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=glens falls
# This is city#: 33
# This is: shilong
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=shilong
# This is city#: 34
# This is: presidente medici
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=presidente medici
# This is city#: 35
# This is: medford
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=medford
# This is city#: 36
# This is: fastiv
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=fastiv
# This is city#: 37
# This is: dongying
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=dongying
# This is city#: 38
# This is: kupino
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kupino
# This is city#: 39
# This is: erzincan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=erzincan
# This is city#: 40
# This is: safranbolu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=safranbolu
# This is city#: 41
# This is: puerto colombia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=puerto colombia
# This is city#: 42
# This is: benidorm
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=benidorm
# This is city#: 43
# This is: qinzhou
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=qinzhou
# This is city#: 44
# This is: cradock
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=cradock
# This is city#: 45
# This is: monte alegre
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=monte alegre
# This is city#: 46
# This is: danshui
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=danshui
# This is city#: 47
# This is: arica
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=arica
# This is city#: 48
# This is: tuljapur
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tuljapur
# This is city#: 49
# This is: medicine hat
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=medicine hat
# This is city#: 50
# This is: fort frances
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=fort frances
# This is city#: 51
# This is: sangmelima
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sangmelima
# This is city#: 52
# This is: jingdezhen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=jingdezhen
# This is city#: 53
# This is: townsville
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=townsville
# This is city#: 54
# This is: kumano
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kumano
# This is city#: 55
# This is: ilulissat
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ilulissat
# This is city#: 56
# This is: aloleng
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=aloleng
# This is city#: 57
# This is: neuquen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=neuquen
# This is city#: 58
# This is: alabaster
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=alabaster
# This is city#: 59
# This is: pipri
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=pipri
# This is city#: 60
# This is: honiara
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=honiara
# This is city#: 61
# This is: oeiras do para
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=oeiras do para
# This is city#: 62
# This is: aginskoye
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=aginskoye
# This is city#: 63
# This is: bilma
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bilma
# This is city#: 64
# This is: kirakira
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kirakira
# This is city#: 65
# This is: davila
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=davila
# This is city#: 66
# This is: bela
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bela
# This is city#: 67
# This is: dhidhdhoo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=dhidhdhoo
# This is city#: 68
# This is: lakhisarai
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=lakhisarai
# This is city#: 69
# This is: trinidad
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=trinidad
# This is city#: 70
# This is: mogwase
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mogwase
# This is city#: 71
# This is: cotonou
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=cotonou
# This is city#: 72
# This is: moron
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=moron
# This is city#: 73
# This is: tiznit
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tiznit
# This is city#: 74
# This is: trogir
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=trogir
# This is city#: 75
# This is: debre tabor
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=debre tabor
# No data for this city: shkotovo-22
# This is city#: 76
# This is: shkotovo-22
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=shkotovo-22
# This is city#: 77
# This is: victoria
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=victoria
# No data for this city: betioky
# This is city#: 78
# This is: betioky
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=betioky
# No data for this city: shchuchye
# This is city#: 79
# This is: shchuchye
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=shchuchye
# This is city#: 80
# This is: barreirinha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=barreirinha
# This is city#: 81
# This is: margate
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=margate
# This is city#: 82
# This is: iberia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=iberia
# This is city#: 83
# This is: macapa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=macapa
# This is city#: 84
# This is: porteirinha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=porteirinha
# This is city#: 85
# This is: isaka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=isaka
# This is city#: 86
# This is: de-kastri
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=de-kastri
# This is city#: 87
# This is: chuy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=chuy
# This is city#: 88
# This is: mishkino
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mishkino
# This is city#: 89
# This is: gaurnadi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=gaurnadi
# This is city#: 90
# This is: robertson
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=robertson
# This is city#: 91
# This is: uppsala
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=uppsala
# This is city#: 92
# This is: schenectady
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=schenectady
# This is city#: 93
# This is: west plains
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=west plains
# This is city#: 94
# This is: bubaque
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bubaque
# This is city#: 95
# This is: del rio
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=del rio
# This is city#: 96
# This is: tobias barreto
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tobias barreto
# This is city#: 97
# This is: troy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=troy
# This is city#: 98
# This is: nova olimpia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=nova olimpia
# This is city#: 99
# This is: neumunster
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=neumunster
# This is city#: 100
# This is: myaundzha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=myaundzha
# This is city#: 101
# This is: bouafle
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bouafle
# No data for this city: yusva
# This is city#: 102
# This is: yusva
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=yusva
# This is city#: 103
# This is: urbana
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=urbana
# This is city#: 104
# This is: weston
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=weston
# This is city#: 105
# This is: vila franca do campo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=vila franca do campo
# This is city#: 106
# This is: zonguldak
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=zonguldak
# No data for this city: mrirt
# This is city#: 107
# This is: mrirt
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mrirt
# This is city#: 108
# This is: mwingi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mwingi
# No data for this city: ajoloapan
# This is city#: 109
# This is: ajoloapan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ajoloapan
# This is city#: 110
# This is: krasnoyarskiy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=krasnoyarskiy
# This is city#: 111
# This is: jacareacanga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=jacareacanga
# This is city#: 112
# This is: ozinki
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ozinki
# This is city#: 113
# This is: carbonia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=carbonia
# This is city#: 114
# This is: tsiroanomandidy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tsiroanomandidy
# This is city#: 115
# This is: pervouralsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=pervouralsk
# This is city#: 116
# This is: xichang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=xichang
# This is city#: 117
# This is: kualakapuas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kualakapuas
# This is city#: 118
# This is: supe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=supe
# This is city#: 119
# This is: goias
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=goias
# This is city#: 120
# This is: cheremukhovo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=cheremukhovo
# This is city#: 121
# This is: ubauro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ubauro
# This is city#: 122
# This is: easton
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=easton
# No data for this city: kousseri
# This is city#: 123
# This is: kousseri
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kousseri
# This is city#: 124
# This is: burns lake
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=burns lake
# This is city#: 125
# This is: hungund
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=hungund
# This is city#: 126
# This is: mazsalaca
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mazsalaca
# This is city#: 127
# This is: trapani
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=trapani
# This is city#: 128
# This is: letlhakane
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=letlhakane
# This is city#: 129
# This is: magistralnyy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=magistralnyy
# This is city#: 130
# This is: galashki
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=galashki
# This is city#: 131
# This is: mahbubabad
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mahbubabad
# This is city#: 132
# This is: stillwater
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=stillwater
# This is city#: 133
# This is: koltubanovskiy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=koltubanovskiy
# This is city#: 134
# This is: gornopravdinsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=gornopravdinsk
# This is city#: 135
# This is: inuvik
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=inuvik
# This is city#: 136
# This is: jacobina
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=jacobina
# This is city#: 137
# This is: sokolo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sokolo
# This is city#: 138
# This is: kaunas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kaunas
# This is city#: 139
# This is: novosil
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=novosil
# No data for this city: sinkat
# This is city#: 140
# This is: sinkat
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sinkat
# This is city#: 141
# This is: alamos
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=alamos
# No data for this city: naftah
# This is city#: 142
# This is: naftah
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=naftah
# This is city#: 143
# This is: visby
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=visby
# This is city#: 144
# This is: malkapur
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=malkapur
# This is city#: 145
# This is: barstow
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=barstow
# This is city#: 146
# This is: egersund
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=egersund
# This is city#: 147
# This is: cortes
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=cortes
# This is city#: 148
# This is: guadalajara
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=guadalajara
# This is city#: 149
# This is: prince george
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=prince george
# This is city#: 150
# This is: aksarka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=aksarka
# This is city#: 151
# This is: mathbaria
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mathbaria
# This is city#: 152
# This is: pizhma
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=pizhma
# This is city#: 153
# This is: haflong
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=haflong
# This is city#: 154
# This is: krasnokamensk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=krasnokamensk
# This is city#: 155
# This is: santo augusto
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=santo augusto
# No data for this city: sofiysk
# This is city#: 156
# This is: sofiysk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sofiysk
# This is city#: 157
# This is: tabory
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tabory
# This is city#: 158
# This is: jiangyou
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=jiangyou
# This is city#: 159
# This is: san juan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=san juan
# This is city#: 160
# This is: ocean city
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ocean city
# This is city#: 161
# This is: kanchanaburi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kanchanaburi
# This is city#: 162
# This is: joensuu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=joensuu
# No data for this city: kondratovo
# This is city#: 163
# This is: kondratovo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kondratovo
# This is city#: 164
# This is: urucui
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=urucui
# This is city#: 165
# This is: mikun
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mikun
# This is city#: 166
# This is: talnakh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=talnakh
# This is city#: 167
# This is: tete
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tete
# This is city#: 168
# This is: linkuva
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=linkuva
# This is city#: 169
# This is: turgoyak
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=turgoyak
# This is city#: 170
# This is: rancharia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=rancharia
# This is city#: 171
# This is: concepcion del uruguay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=concepcion del uruguay
# This is city#: 172
# This is: cremona
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=cremona
# This is city#: 173
# This is: midrand
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=midrand
# This is city#: 174
# This is: el porvenir
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=el porvenir
# This is city#: 175
# This is: nastola
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=nastola
# This is city#: 176
# This is: zarubino
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=zarubino
# This is city#: 177
# This is: dongobesh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=dongobesh
# This is city#: 178
# This is: varias
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=varias
# This is city#: 179
# This is: sesheke
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sesheke
# This is city#: 180
# This is: nahariyya
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=nahariyya
# This is city#: 181
# This is: subate
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=subate
# This is city#: 182
# This is: barao de melgaco
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=barao de melgaco
# No data for this city: ahumada
# This is city#: 183
# This is: ahumada
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ahumada
# This is city#: 184
# This is: mucurapo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mucurapo
# This is city#: 185
# This is: bridlington
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bridlington
# This is city#: 186
# This is: bydgoszcz
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bydgoszcz
# This is city#: 187
# This is: hillsboro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=hillsboro
# This is city#: 188
# This is: maloh
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=maloh
# This is city#: 189
# This is: shatsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=shatsk
# This is city#: 190
# This is: laem sing
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=laem sing
# This is city#: 191
# This is: sturgeon bay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sturgeon bay
# This is city#: 192
# This is: nanchang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=nanchang
# This is city#: 193
# This is: atagay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=atagay
# This is city#: 194
# This is: lima
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=lima
# This is city#: 195
# This is: colborne
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=colborne
# This is city#: 196
# This is: reforma
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=reforma
# This is city#: 197
# This is: key west
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=key west
# This is city#: 198
# This is: harlingen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=harlingen
# This is city#: 199
# This is: huangpi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=huangpi
# This is city#: 200
# This is: harrison
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=harrison
# This is city#: 201
# This is: artesia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=artesia
# This is city#: 202
# This is: mocajuba
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mocajuba
# This is city#: 203
# This is: san benedetto del tronto
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=san benedetto del tronto
# This is city#: 204
# This is: ulety
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ulety
# No data for this city: jinchengjiang
# This is city#: 205
# This is: jinchengjiang
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=jinchengjiang
# This is city#: 206
# This is: shizuishan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=shizuishan
# This is city#: 207
# This is: ouadda
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ouadda
# This is city#: 208
# This is: kathmandu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kathmandu
# This is city#: 209
# This is: shenjiamen
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=shenjiamen
# This is city#: 210
# This is: palora
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=palora
# No data for this city: tiruvottiyur
# This is city#: 211
# This is: tiruvottiyur
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tiruvottiyur
# This is city#: 212
# This is: shitkino
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=shitkino
# This is city#: 213
# This is: gondar
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=gondar
# This is city#: 214
# This is: tonekabon
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tonekabon
# This is city#: 215
# This is: massakory
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=massakory
# This is city#: 216
# This is: wawa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=wawa
# This is city#: 217
# This is: bhainsa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bhainsa
# This is city#: 218
# This is: lajas
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=lajas
# This is city#: 219
# This is: lubao
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=lubao
# This is city#: 220
# This is: burriana
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=burriana
# This is city#: 221
# This is: bosaso
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bosaso
# This is city#: 222
# This is: korcula
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=korcula
# This is city#: 223
# This is: male
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=male
# This is city#: 224
# This is: mori
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mori
# This is city#: 225
# This is: kapuskasing
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kapuskasing
# This is city#: 226
# This is: soure
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=soure
# This is city#: 227
# This is: shumskiy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=shumskiy
# This is city#: 228
# This is: mbini
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mbini
# This is city#: 229
# This is: bonito
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bonito
# This is city#: 230
# This is: taguatinga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=taguatinga
# This is city#: 231
# This is: port blair
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=port blair
# This is city#: 232
# This is: provost
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=provost
# This is city#: 233
# This is: goldsboro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=goldsboro
# This is city#: 234
# This is: katobu
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=katobu
# This is city#: 235
# This is: severodvinsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=severodvinsk
# This is city#: 236
# This is: kalispell
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kalispell
# This is city#: 237
# This is: rafsanjan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=rafsanjan
# This is city#: 238
# This is: venice
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=venice
# This is city#: 239
# This is: magadan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=magadan
# This is city#: 240
# This is: santa rita
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=santa rita
# This is city#: 241
# This is: kawardha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kawardha
# This is city#: 242
# This is: sergeyevka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sergeyevka
# This is city#: 243
# This is: abbeville
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=abbeville
# This is city#: 244
# This is: wencheng
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=wencheng
# This is city#: 245
# This is: nola
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=nola
# This is city#: 246
# This is: delvine
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=delvine
# This is city#: 247
# This is: drochia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=drochia
# This is city#: 248
# This is: kaitangata
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kaitangata
# This is city#: 249
# This is: naliya
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=naliya
# This is city#: 250
# This is: sangueya
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sangueya
# This is city#: 251
# This is: murindo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=murindo
# This is city#: 252
# This is: ambanja
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ambanja
# This is city#: 253
# This is: sur
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sur
# This is city#: 254
# This is: msanga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=msanga
# This is city#: 255
# This is: zakamensk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=zakamensk
# This is city#: 256
# This is: katakwi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=katakwi
# This is city#: 257
# This is: srirampur
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=srirampur
# This is city#: 258
# This is: herrin
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=herrin
# This is city#: 259
# This is: yara
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=yara
# This is city#: 260
# This is: san jose de guanipa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=san jose de guanipa
# This is city#: 261
# This is: dongkan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=dongkan
# This is city#: 262
# This is: labuan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=labuan
# This is city#: 263
# This is: arrifes
# ...
# This is city#: 411
# This is: koson
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=koson
# This is city#: 412
# This is: tura
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tura
# This is city#: 413
# This is: chalmette
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=chalmette
# This is city#: 414
# This is: meybod
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=meybod
# This is city#: 415
# This is: blind river
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=blind river
# This is city#: 416
# This is: morro da fumaca
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=morro da fumaca
# This is city#: 417
# This is: emporia
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=emporia
# This is city#: 418
# This is: broome
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=broome
# This is city#: 419
# This is: viransehir
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=viransehir
# This is city#: 420
# This is: archidona
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=archidona
# This is city#: 421
# This is: manicore
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=manicore
# This is city#: 422
# This is: hirtshals
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=hirtshals
# This is city#: 423
# This is: san antonio
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=san antonio
# This is city#: 424
# This is: santomera
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=santomera
# This is city#: 425
# This is: villanueva
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=villanueva
# This is city#: 426
# This is: quchan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=quchan
# This is city#: 427
# This is: novaya ladoga
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=novaya ladoga
# This is city#: 428
# This is: umm bab
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=umm bab
# This is city#: 429
# This is: kundiawa
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kundiawa
# This is city#: 430
# This is: langham
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=langham
# This is city#: 431
# This is: laje
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=laje
# This is city#: 432
# This is: cave spring
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=cave spring
# This is city#: 433
# This is: kamuli
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kamuli
# This is city#: 434
# This is: capao bonito
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=capao bonito
# This is city#: 435
# This is: thika
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=thika
# This is city#: 436
# This is: savinka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=savinka
# This is city#: 437
# This is: athy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=athy
# No data for this city: wampusirpi
# This is city#: 438
# This is: wampusirpi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=wampusirpi
# This is city#: 439
# This is: ceahlau
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ceahlau
# This is city#: 440
# This is: santa isabel
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=santa isabel
# This is city#: 441
# This is: ratnagiri
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ratnagiri
# This is city#: 442
# This is: kaka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kaka
# This is city#: 443
# This is: mendeleyevo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mendeleyevo
# This is city#: 444
# This is: rozivka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=rozivka
# This is city#: 445
# This is: eldorado
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=eldorado
# This is city#: 446
# This is: nikolskoye
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=nikolskoye
# This is city#: 447
# This is: togur
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=togur
# This is city#: 448
# This is: hikari
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=hikari
# This is city#: 449
# This is: cherepovets
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=cherepovets
# This is city#: 450
# This is: mugur-aksy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mugur-aksy
# This is city#: 451
# This is: palatka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=palatka
# This is city#: 452
# This is: paros
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=paros
# This is city#: 453
# This is: lalibela
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=lalibela
# This is city#: 454
# This is: pankrushikha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=pankrushikha
# This is city#: 455
# This is: hachinohe
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=hachinohe
# This is city#: 456
# This is: saeby
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=saeby
# This is city#: 457
# This is: mabay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mabay
# This is city#: 458
# This is: ballitoville
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ballitoville
# This is city#: 459
# This is: nimaparha
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=nimaparha
# This is city#: 460
# This is: yongan
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=yongan
# This is city#: 461
# This is: ovre ardal
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ovre ardal
# This is city#: 462
# This is: dickinson
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=dickinson
# This is city#: 463
# This is: gordeyevka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=gordeyevka
# This is city#: 464
# This is: torbay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=torbay
# This is city#: 465
# This is: portobelo
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=portobelo
# This is city#: 466
# This is: palmeiras de goias
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=palmeiras de goias
# This is city#: 467
# This is: bati
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=bati
# This is city#: 468
# This is: kavos
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=kavos
# This is city#: 469
# This is: tatsuno
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tatsuno
# This is city#: 470
# This is: sorsk
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sorsk
# This is city#: 471
# This is: biltine
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=biltine
# This is city#: 472
# This is: pedra azul
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=pedra azul
# This is city#: 473
# This is: livramento
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=livramento
# This is city#: 474
# This is: dengzhou
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=dengzhou
# This is city#: 475
# This is: liberal
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=liberal
# This is city#: 476
# This is: munster
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=munster
# This is city#: 477
# This is: valkeala
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=valkeala
# This is city#: 478
# This is: teno
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=teno
# This is city#: 479
# This is: lukhovitsy
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=lukhovitsy
# This is city#: 480
# This is: rikitea
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=rikitea
# This is city#: 481
# This is: murray
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=murray
# This is city#: 482
# This is: fare
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=fare
# This is city#: 483
# This is: alibag
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=alibag
# This is city#: 484
# This is: areia branca
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=areia branca
# This is city#: 485
# This is: ivanteyevka
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=ivanteyevka
# This is city#: 486
# This is: iroquois falls
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=iroquois falls
# This is city#: 487
# This is: maues
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=maues
# No data for this city: galgani
# This is city#: 488
# This is: galgani
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=galgani
# This is city#: 489
# This is: mehriz
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=mehriz
# This is city#: 490
# This is: sandy bay
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=sandy bay
# This is city#: 491
# This is: seydi
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=seydi
# This is city#: 492
# This is: san isidro
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=san isidro
# This is city#: 493
# This is: teknaf
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=teknaf
# This is city#: 494
# This is: siverek
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=siverek
# This is city#: 495
# This is: killorglin
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=killorglin
# This is city#: 496
# This is: butaritari
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=butaritari
# This is city#: 497
# This is: tekeli
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=tekeli
# This is city#: 498
# This is: castanheira de pera
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=castanheira de pera
# No data for this city: louisbourg
# This is city#: 499
# This is: louisbourg
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=louisbourg
# This is city#: 500
# This is: halmstad
# This is the requested URL: http://api.openweathermap.org/data/2.5/weather?appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial&q=halmstad

# %%
samplecity = samplecity[samplecity.latitude != ""]
samplecity
# Out:
#                      city country latitude longitude temperature humidity  \
# 7237             poddorye      ru       57        57          40       93
# 783           sao gotardo      br      -19       -19          69       87
# 6025              rassvet      ru       47        47          50       76
# 6993           westerland      de       52        52          40       75
# 3995              sonipat      in       29        29          73       64
# 1431            purwodadi      id       -7        -7          84       87
# 105        lakes entrance      au      -37       -37          59       76
# 3549     vicente guerrero      mx       16        16          59       70
# 1243              merauke      id       -8        -8          83       92
# 4674                 sari      ir       36        36          57       93
# 7725           porosozero      ru       62        62          28       96
# 5654       terekli-mekteb      ru       44        44          33       74
# 5813               yakima      us       46        46          49       87
# 3365               mahuva      in       21        21          86       91
# 4268           huangchuan      cn       24        24          64       68
# 1029                 sola      vu       58        58          30       86
# 7849            rovaniemi      fi       66        66          15       92
# 305                 salto      uy      -31       -31          63       77
# 1501                 jati      id       24        24          75       35
# 2022               orocue      co        4         4          74       92
# 2069            sarangani      ph        5         5          82      100
# 7845               kiruna      se       67        67          14      100
# 2181                baoro      cf        5         5          68       98
# 3207             frontera      mx       18        18          82       70
# 5537                merke      kz       42        42          33       65
# 6108          bad wurzach      de       47        47          34       99
# 608               yeppoon      au      -23       -23          98       27
# 5596          glens falls      us       43        43          42       81
# 3536              shilong      cn       23        23          78       24
# 1154    presidente medici      br      -11       -11          79       82
# ...                   ...     ...      ...       ...         ...      ...
# 4708              tatsuno      jp       34        34          62       48
# 6945                sorsk      ru       54        54          19       61
# 2952              biltine      td       14        14          77       26
# 956            pedra azul      br      -16       -16          68       96
# 1054           livramento      br       -3        -3          81       83
# 4354             dengzhou      cn       32        32          72       45
# 4723              liberal      us       37        37          58       62
# 6744              munster      de       52        52          32      100
# 7594             valkeala      fi       60        60          30       86
# 187                  teno      cl      -34       -34          64       63
# 7021           lukhovitsy      ru       54        54          46       95
# 2                 rikitea      pf      -23       -23          73      100
# 4734               murray      us       40        40          53       54
# 929                  fare      pf      -16       -16          80      100
# 3164               alibag      in       18        18          86       42
# 1531         areia branca      br      -10       -10          78       69
# 6640          ivanteyevka      ru       55        55          42       93
# 6204       iroquois falls      ca       48        48          28       79
# 1592                maues      br       -3        -3          77       90
# 4151               mehriz      ir       31        31          60       51
# 3080            sandy bay      hn      -42       -42          57       44
# 5040                seydi      tm       13        13          72       78
# 2219           san isidro      ph       16        16          78       75
# 3243               teknaf      bd       20        20          74       97
# 4910              siverek      tr       37        37          42       70
# 6584           killorglin      ie       52        52          37       97
# 1959           butaritari      ki        3         3          85      100
# 5666               tekeli      kz       44        44          53       35
# 5112  castanheira de pera      pt       40        40          46       75
# 7220             halmstad      se       56        56          33       86
#
#      cloudiness wind_speed
# 7237         76         15
# 783          32          6
# 6025          0          6
# 6993          0         10
# 3995          0          4
# 1431          8          5
# 105           0          5
# 3549          0          2
# 1243         12         11
# 4674         75          2
# 7725         80          8
# 5654          0          2
# 5813         90          4
# 3365         44          5
# 4268         75          4
# 1029          0          3
# 7849          0         10
# 305          68          9
# 1501          0          2
# 2022          0          3
# 2069         32         16
# 7845          0          3
# 2181         48          4
# 3207         12         14
# 5537         76          2
# 6108         92         11
# 608           0         11
# 5596         90         11
# 3536          0          6
# 1154         64          2
# ...         ...        ...
# 4708         40          9
# 6945          0          2
# 2952          0         15
# 956          68          3
# 1054          0          4
# 4354          0          5
# 4723          1          8
# 6744         75          8
# 7594         75          9
# 187          44          4
# 7021         80         15
# 2            56         13
# 4734          1          5
# 929          12          9
# 3164          8         11
# 1531         40         14
# 6640         75         11
# 6204         90          5
# 1592         24          4
# 4151         75         11
# 3080         75          9
# 5040          0          2
# 2219         32         14
# 3243         88          3
# 4910          0         11
# 6584          0         10
# 1959         12         11
# 5666         88          4
# 5112         20         10
# 7220         68         10
#
# [464 rows x 8 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Grab list of cities based on coordinates from citipy
citylist = []
count = 0
dup = 'no'

for x in range(-90,90,1):
    for y in range(-180,180,1):
        city = cp.nearest_city(x, y)
        citdict = {}
        citdict['city'] = city.city_name
        citdict['country'] = city.country_code
        citdict['lat'] = x
        citdict['long'] = y
        if len(citylist) == 0:
            citylist.append(citdict)
            count+=1
            continue
        else:
            #Get rid of duplicates
            for city in citylist:
                if city['city'] == citdict['city']:
                    dup = 'yes'
        if dup == 'no':
            citylist.append(citdict)
            count+=1
        else:
            dup = 'no'

print(len(citylist))

# %%
print(citylist[0])

# %%
samplecity

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# import datetime
# date = datetime.date.today()
import time
date = time.strftime("%m/%d/%Y")
plt.scatter(samplecity['latitude'],samplecity['temperature'])
plt.title(f"Temperature (F) vs. Latitude {date}")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.style.use('ggplot')
plt.savefig("Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plt.scatter(latitude,humidity)
plt.scatter(samplecity['latitude'], samplecity['humidity'])
plt.title(f"Humidity (%) vs. Latitude {date}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.style.use('ggplot')
plt.savefig("Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plt.scatter(latitude,cloudy)
plt.scatter(samplecity['latitude'], samplecity['cloudiness'])
plt.title(f"Cloudiness (%) vs. Latitude {date}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.style.use('ggplot')
plt.savefig("Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plt.scatter(latitude,windspeed)
plt.scatter(samplecity['latitude'], samplecity['wind_speed'])
plt.title(f"Wind Speed(mph) vs. Latitude {date}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.style.use('ggplot')
plt.savefig("Wind_Speed.png")
plt.show()

# %%
# samplecity = samplecity[samplecity.latitude != ""]
#above works to remove blank answers
#Make into CSV
samplecity.to_csv("sampleweather.csv", encoding="utf-8", index=False)
df = pd.read_csv("sampleweather.csv")
df.head()
